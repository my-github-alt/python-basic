# %% [markdown]
# # Hello World

# %%
# een lijn met commentaar start met een `#`

def print_hi(name):
    print(f'Hi, {name}!')

naam = 'Python programmeur'

print_hi(naam)
# Out:
# Hi, Python programmeur!

# %% [markdown]
# ## Oefeningen Hello World
#
# Pas de variabele `naam` in de cel hierboven aan en druk op `► Run`
